# %% [markdown]
# Lets get working

# %%
# Import the function from your data_fetch module
import sys, os

project_root = "/Users/rodgersbahati/Developer/Projects/NBA/NBA_Player_Stats_Predictor"
if project_root not in sys.path:
    sys.path.append(project_root)

from utils.data_fetch import get_team_data

# Call the function and print the output
# Retrieve team data using get_team_data
team_data_df = get_team_data()
if not team_data_df.empty:
    print("Team data retrieved successfully:")
    print(team_data_df.head())  # Display the first few rows for a quick check
else:
    print("No team data available.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Import the function from your data_fetch module
# ----> 2 from utils.data_fetch import get_team_data
#       4 # Call the function and print the output
#       5 # Retrieve team data using get_team_data
#       6 team_data_df = get_team_data()
#
# ImportError: cannot import name 'get_team_data' from 'utils.data_fetch' (/Users/rodgersbahati/Developer/Projects/NBA/NBA_Player_Stats_Predictor/utils/data_fetch.py)

# %%
import sys
import os

# Add project root to sys.path to ensure modules are accessible
project_root = (
    "/Users/rodgersbahati/Developer/Projects/NBA/NBA_Player_Stats_Predictor"
)
if project_root not in sys.path:
    sys.path.append(project_root)

# Now try importing the function
from utils.data_fetch import get_team_data

# Retrieve team data using get_team_data
team_data_df = get_team_data()
if not team_data_df.empty:
    print("Team data retrieved successfully:")
    display(team_data_df.head())
else:
    print("No team data available.")
# Out:
# Team data retrieved successfully:
#       TEAM_ID          TEAM_NAME  GP   W   L  W_PCT   MIN   FGM   FGA  FG_PCT  \
# 0  1611661330      Atlanta Dream  44  30  14  0.682  40.1  30.1  67.8   0.443
# 1  1610612737      Atlanta Hawks  12   7   5  0.583  44.8  39.4  83.4   0.473
# 2  1610612738     Boston Celtics  12   7   5  0.583  44.7  37.7  87.6   0.430
# 3  1610612751      Brooklyn Nets  11   1  10  0.091  44.4  35.8  82.2   0.436
# 4  1610612766  Charlotte Hornets  13   9   4  0.692  44.3  38.6  81.8   0.472
#
#    ...  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0  ...        31        25         2        40        23          5        1
# 1  ...        10         5        12        19        16         17       19
# 2  ...         8        23         6         8        12         31       32
# 3  ...        22        30        32        24        42         33       41
# 4  ...         2         3        22        38        24         13       15
#
# ...

# %%
import os
import sys

# Add the project root to the system path to ensure relative imports work
sys.path.append(os.path.abspath(".."))  # Adjust ".." if your notebook is not in the project root

from utils.data_fetch import fetch_data, get_player_stats


player_id = ("8ec91366-faea-4196-bbfd-b8fab7434795")  # Example player ID for Stephen Curry)
player_stats = get_player_stats(player_id)

# Display the first few rows of the player's season stats
print(player_stats.head())


# Test game data (replace with actual season year and team ID)
# team_data = get_team_data("2023", "583ec825-fb46-11e1-82cb-f4ce4684ea4c")
# print(team_data.head())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 7
#       4 # Add the project root to the system path to ensure relative imports work
#       5 sys.path.append(os.path.abspath(".."))  # Adjust ".." if your notebook is not in the project root
# ----> 7 from utils.data_fetch import fetch_data, get_player_stats
#      10 player_id = ("8ec91366-faea-4196-bbfd-b8fab7434795")  # Example player ID for Stephen Curry)
#      11 player_stats = get_player_stats(player_id)
#
# ImportError: cannot import name 'fetch_data' from 'utils.data_fetch' (/Users/rodgersbahati/Developer/Projects/NBA/NBA_Player_Stats_Predictor/utils/data_fetch.py)

# %%
from utils.data_fetch import get_player_stats

player_id = "8ec91366-faea-4196-bbfd-b8fab7434795"
stats = get_player_stats(player_id)


# print the stats in a table format
from IPython.display import display
display(stats)
# Out:
# Player '8ec91366-faea-4196-bbfd-b8fab7434795' not found.
# Empty DataFrame
# Columns: []
# Index: []
